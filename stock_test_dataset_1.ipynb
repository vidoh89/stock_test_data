# %%
# Lib resource <yfinance>:collects stock data.
# !pip install yfinance

# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
import yfinance as yf

# %% [markdown]
# Step 1. Pull in test data from yf

# %%
# Test data for the S&P500
sp500 = yf.Ticker("^GSPC")

# Collect 'max' period :
# Period=['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', max]
sp500.history(period="max")

sp500.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 6068.5,
#  'open': 6025.08,
#  'dayLow': 6003.0,
#  'dayHigh': 6049.15,
#  'regularMarketPreviousClose': 6068.5,
#  'regularMarketOpen': 6025.08,
#  'regularMarketDayLow': 6003.0,
#  'regularMarketDayHigh': 6049.15,
#  'volume': 812586811,
#  'regularMarketVolume': 812586811,
#  'averageVolume': 4258371833,
#  'averageVolume10days': 4595498000,
#  'averageDailyVolume10Day': 4595498000,
#  'bid': 6039.97,
#  'ask': 6044.1,
#  'fiftyTwoWeekLow': 4946.0,
#  'fiftyTwoWeekHigh': 6128.18,
#  'fiftyDayAverage': 6003.779,
#  'twoHundredDayAverage': 5665.622,
#  'currency': 'USD',
#  '52WeekChange': 21.35495,
#  'exchange': 'SNP',
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'underlyingSymbol': '^GSPC',
#  'shortName': 'S&P 500',
#  'longName': 'S&P 500',
#  'firstTradeDateEpochUtc': -1325583000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '8ffd55d1-3d1d-3733-a480-56768bc708e6',
#  'messageBoardId': 'finmb_INDEXGSPC',
#  'gmtOffSetMilliseconds': -18000000,
#  'trailingPegRatio': None}
