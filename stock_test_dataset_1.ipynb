# %%
# Lib resource <pandas-datareader>:collects stock data.
# !pip install pandas_datareader

# %%
import pandas as pd
import datetime as dt
from pandas_datareader import data as pdr

# %% [markdown]
# Step 1. Specify date range for analysis

# %%
end = dt.datetime.now()

start = end - dt.timedelta(days=5000)
start,end
# Out:
# (datetime.datetime(2011, 6, 6, 8, 25, 7, 770060),
#  datetime.datetime(2025, 2, 12, 8, 25, 7, 770060))
